# %%
%gnuplot inline jpeg enhanced background rgb "#F5DA81"

# %%
g(x) = cos(a*x)/a
plot a=1, g(x), \
     a=2, g(x)

# %%
%%gnuplot
plot sin(x)

# %%
https://github.com/has2k1/gnuplot_kernel/blob/master/examples/gnuplot-magic.ipynb

# %%
%load_ext gnuplot_kernel
# Out:
# %load_ext gnuplot_kernel
# ^
# invalid command
